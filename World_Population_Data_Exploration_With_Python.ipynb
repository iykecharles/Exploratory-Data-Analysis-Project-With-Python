# %%
#Loading the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#loading the data
df = pd.read_csv('C:\\Users\\Lenovo\\2023Python\\data analysis\\world_population_data.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
#summary of the data at a glance
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %%
#dataframe summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
# Rank                           234 non-null int64
# CCA3                           234 non-null object
# Country                        234 non-null object
# Capital                        234 non-null object
# Continent                      234 non-null object
# 2022 Population                230 non-null float64
# 2020 Population                233 non-null float64
# 2015 Population                230 non-null float64
# 2010 Population                227 non-null float64
# 2000 Population                227 non-null float64
# 1990 Population                229 non-null float64
# 1980 Population                229 non-null float64
# 1970 Population                230 non-null float64
# Area (km²)                     232 non-null float64
# Density (per km²)              230 non-null float64
# Growth Rate                    232 non-null float64
# ...

# %%
#Creating a copy of our dataset
backup = df.copy()

# %%
df.values
# Out:
# array([[36, 'AFG', 'Afghanistan', ..., 63.0587, 1.0257, 0.52],
#        [138, 'ALB', 'Albania', ..., 98.8702, 0.9957, 0.04],
#        [34, 'DZA', 'Algeria', ..., 18.8531, 1.0164, 0.56],
#        ...,
#        [46, 'YEM', 'Yemen', ..., 63.8232, 1.0217, 0.42],
#        [63, 'ZMB', 'Zambia', ..., 26.5976, 1.028, 0.25],
#        [74, 'ZWE', 'Zimbabwe', ..., 41.7665, 1.0204, 0.2]], dtype=object)

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
#Viewing the data. the first 10 lines of the data at a glance
df.head(10)
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
#checking for duplicated values. I would use the sum() method to count duplicated rows in the Datafram.
df.duplicated().sum()
# Out:
# 0

# %%
#for identification sake, i would set 'Country' to be the index.
df.set_index('Country', inplace = True)
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
#rank of the most populated countries in descending order.
#df.sort_values(by=['Rank'])
df.sort_values(by=['2022 Population'], ascending=False)
# Out:
#                                   Rank CCA3              Capital  \
# Country
# China                                1  CHN              Beijing
# India                                2  IND            New Delhi
# United States                        3  USA     Washington, D.C.
# Indonesia                            4  IDN              Jakarta
# Pakistan                             5  PAK            Islamabad
# Nigeria                              6  NGA                Abuja
# Brazil                               7  BRA             Brasilia
# Bangladesh                           8  BGD                Dhaka
# Russia                               9  RUS               Moscow
# Mexico                              10  MEX          Mexico City
# Japan                               11  JPN                Tokyo
# Ethiopia                            12  ETH          Addis Ababa
# Philippines                         13  PHL               Manila
# ...

# %%
#geting the rank of the most populous european nations
df[df['Continent'].str.contains('Europe')].sort_values(by=['2022 Population'], ascending=False)
# Out:
#                         Rank CCA3           Capital Continent  \
# Country
# Russia                     9  RUS            Moscow    Europe
# Germany                   19  DEU            Berlin    Europe
# United Kingdom            21  GBR            London    Europe
# France                    23  FRA             Paris    Europe
# Italy                     25  ITA              Rome    Europe
# Spain                     30  ESP            Madrid    Europe
# Poland                    37  POL            Warsaw    Europe
# Ukraine                   38  UKR              Kiev    Europe
# Romania                   64  ROU         Bucharest    Europe
# Netherlands               71  NLD         Amsterdam    Europe
# Belgium                   81  BEL          Brussels    Europe
# Sweden                    87  SWE         Stockholm    Europe
# Czech Republic            88  CZE            Prague    Europe
# Greece                    90  GRC            Athens    Europe
# ...

# %%
#top 10 most populous country in 2022.
df.sort_values(by=['2022 Population'], ascending=False).head(10)
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# China             1  CHN           Beijing           Asia     1.425887e+09
# India             2  IND         New Delhi           Asia     1.417173e+09
# United States     3  USA  Washington, D.C.  North America     3.382899e+08
# Indonesia         4  IDN           Jakarta           Asia     2.755013e+08
# Pakistan          5  PAK         Islamabad           Asia     2.358249e+08
# Nigeria           6  NGA             Abuja         Africa     2.185412e+08
# Brazil            7  BRA          Brasilia  South America     2.153135e+08
# Bangladesh        8  BGD             Dhaka           Asia     1.711864e+08
# Russia            9  RUS            Moscow         Europe     1.447133e+08
# Mexico           10  MEX       Mexico City  North America     1.275041e+08
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# ...

# %%
uk_population = df[df['Country'] == 'United Kingdom']['2022 Population'].values[0]
european_countries = df[df['Continent'].str.contains('Europe')]
result = european_countries[european_countries['2022 Population'] > uk_population][['Country', '2022 Population']]
result
# Out:
#      Country  2022 Population
# 74   Germany       83369843.0
# 171   Russia      144713314.0

# %%
uk_population = df[df['Country'] == 'United Kingdom']['2022 Population']

# %%
uk_population
# Out:
# 220    67508936.0
# Name: 2022 Population, dtype: float64

# %%
# mean of the populations of different continents
df.groupby('Continent').mean()
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# ...

# %%
# sum of the populations of different continents
df.groupby('Continent').sum()
# Out:
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253     1.425529e+09     1.360672e+09     1.156664e+09
# Asia           3878     4.720042e+09     4.652802e+09     4.458250e+09
# Europe         6225     7.377132e+08     7.457922e+08     7.363453e+08
# North America  6437     6.002961e+08     5.942366e+08     5.703838e+08
# Oceania        4336     4.502050e+07     4.393343e+07     4.040328e+07
# South America  1366     4.368166e+08     4.315300e+08     4.131344e+08
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.020503e+09     8.175085e+08     6.371100e+08
# Asia              4.187125e+09     3.706718e+09     2.334720e+09
# Europe            7.356139e+08     7.260666e+08     7.096898e+08
# North America     5.427207e+08     4.860696e+08     4.212664e+08
# Oceania           3.710276e+07     3.122278e+07     2.674382e+07
# ...

# %%
df.groupby('Continent').max()
# Out:
#                Rank CCA3     Capital  2022 Population  2020 Population  \
# Continent
# Africa          196  ZWE     Yaounde     2.185412e+08     2.083274e+08
# Asia            175  YEM     Yerevan     1.425887e+09     1.424930e+09
# Europe          234  VAT      Zagreb     1.447133e+08     1.456173e+08
# North America   230  VIR  Willemstad     3.382899e+08     3.359420e+08
# Oceania         233  WSM       Yaren     2.617741e+07     2.567005e+07
# South America   231  VEN       Sucre     2.153135e+08     2.131963e+08
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa            1.839958e+08     1.609529e+08     1.228520e+08
# Asia              1.393715e+09     1.348191e+09     1.264099e+09
# Europe            1.446684e+08     1.432426e+08     1.468448e+08
# North America     3.246078e+08     3.111828e+08     2.823986e+08
# Oceania           2.382024e+07     2.201917e+07     1.901796e+07
# ...

# %%
df.groupby('Continent').mean().sort_values(by=['2022 Population'], ascending=False)
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# South America     2.678940e+07     2.501589e+07     2.122474e+07
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# ...

# %%
df.groupby('Continent').max().sort_values(by=['2022 Population'], ascending=False)
# Out:
#                Rank CCA3                       Country     Capital  \
# Continent
# Asia            175  YEM                         Yemen     Yerevan
# North America   230  VIR  United States Virgin Islands  Willemstad
# Africa          196  ZWE                      Zimbabwe     Yaounde
# South America   231  VEN                     Venezuela       Sucre
# Europe          234  VAT                  Vatican City      Zagreb
# Oceania         233  WSM             Wallis and Futuna       Yaren
#
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia              1.425887e+09     1.424930e+09     1.393715e+09
# North America     3.382899e+08     3.359420e+08     3.246078e+08
# Africa            2.185412e+08     2.083274e+08     1.839958e+08
# South America     2.153135e+08     2.131963e+08     2.051882e+08
# Europe            1.447133e+08     1.456173e+08     1.446684e+08
# Oceania           2.617741e+07     2.567005e+07     2.382024e+07
#
# ...

# %%
df.loc[(df['Continent'] == 'Africa') & (df['Country'] == 'Nigeria')]
# Out:
#      Rank CCA3  Country Capital Continent  2022 Population  2020 Population  \
# 149     6  NGA  Nigeria   Abuja    Africa      218541212.0      208327405.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 149      183995785.0      160952853.0      122851984.0       95214257.0
#
#      1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 149       72951439.0       55569264.0    923768.0           236.5759
#
#      Growth Rate  World Population Percentage
# 149       1.0241                         2.74

# %%
df
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
#using loc index position
df.iloc[[0, 1, -2, -1]]
# Out:
#      Rank CCA3      Country Capital Continent  2022 Population  \
# 0      36  AFG  Afghanistan   Kabul      Asia       41128771.0
# 1     138  ALB      Albania  Tirana    Europe        2842321.0
# 232    63  ZMB       Zambia  Lusaka    Africa       20017675.0
# 233    74  ZWE     Zimbabwe  Harare    Africa       16320537.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230.0       33753499.0       28189672.0       19542982.0
# 1          2866849.0        2882481.0        2913399.0        3182021.0
# 232       18927715.0              NaN       13792086.0        9891136.0
# 233       15669666.0       14154937.0       12839771.0       11834676.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796.0       12486631.0       10752971.0    652230.0
# 1          3295066.0        2941651.0        2324731.0     28748.0
# 232        7686401.0        5720438.0        4281671.0    752612.0
# ...

# %%
df.iloc[[0, 1], [2, 5]]
# Out:
#        Country  2022 Population
# 0  Afghanistan       41128771.0
# 1      Albania        2842321.0

# %%
df.loc[(df['Continent'] == 'Europe') & (df['CCA3'] == 'AND')]     #preffered if columsn and rows are to be selected
#df[(df['Continent'] == 'Europe') & (df['CCA3'] == 'AND')]
# Out:
#          Rank CCA3           Capital Continent  2022 Population  \
# Country
# Andorra   203  AND  Andorra la Vella    Europe          79824.0
#
#          2020 Population  2015 Population  2010 Population  2000 Population  \
# Country
# Andorra          77700.0          71746.0          71519.0          66097.0
#
#          1990 Population  1980 Population  1970 Population  Area (km²)  \
# Country
# Andorra          53569.0          35611.0          19860.0       468.0
#
#          Density (per km²)  Growth Rate  World Population Percentage
# Country
# Andorra           170.5641         1.01                          0.0

# %%
#Grouping
df.groupby('Continent').max()
# Out:
#                Rank CCA3     Capital  2022 Population  2020 Population  \
# Continent
# Africa          196  ZWE     Yaounde     2.185412e+08     2.083274e+08
# Asia            175  YEM     Yerevan     1.425887e+09     1.424930e+09
# Europe          234  VAT      Zagreb     1.447133e+08     1.456173e+08
# North America   230  VIR  Willemstad     3.382899e+08     3.359420e+08
# Oceania         233  WSM       Yaren     2.617741e+07     2.567005e+07
# South America   231  VEN       Sucre     2.153135e+08     2.131963e+08
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa            1.839958e+08     1.609529e+08     1.228520e+08
# Asia              1.393715e+09     1.348191e+09     1.264099e+09
# Europe            1.446684e+08     1.432426e+08     1.468448e+08
# North America     3.246078e+08     3.111828e+08     2.823986e+08
# Oceania           2.382024e+07     2.201917e+07     1.901796e+07
# ...

# %%
#Grouping
df.groupby('Continent')['2015 Population'].max()
# Out:
# Continent
# Africa           1.839958e+08
# Asia             1.393715e+09
# Europe           1.446684e+08
# North America    3.246078e+08
# Oceania          2.382024e+07
# South America    2.051882e+08
# Name: 2015 Population, dtype: float64

# %%
#Grouping
df.groupby('Continent')['2022 Population'].max()
# Out:
# Continent
# Africa           2.185412e+08
# Asia             1.425887e+09
# Europe           1.447133e+08
# North America    3.382899e+08
# Oceania          2.617741e+07
# South America    2.153135e+08
# Name: 2022 Population, dtype: float64

# %%
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
df.groupby(['Rank', 'Country', 'Growth Rate'])[['2022 Population', 'World Population Percentage']].mean()
# Out:
#                                                             2022 Population  \
# Continent     Country                          Growth Rate
# Africa        Algeria                          1.0164          4.490322e+07
#               Angola                           1.0315          3.558899e+07
#               Benin                            1.0274          1.335286e+07
#               Botswana                         1.0162          2.630296e+06
#               Burkina Faso                     1.0259          2.267376e+07
#               Burundi                          1.0270          1.288958e+07
#               Cameroon                         1.0263          2.791454e+07
#               Cape Verde                       1.0089          5.931490e+05
#               Central African Republic         1.0224          5.579144e+06
#               Chad                             1.0316          1.772332e+07
#               Comoros                          1.0184          8.367740e+05
# ...

# %%
df.groupby(['Country', 'Growth Rate'])[['2022 Population', 'World Population Percentage']].mean().reset_index()
# Out:
#                               Country  Growth Rate  2022 Population  \
# 0                         Afghanistan       1.0257     4.112877e+07
# 1                             Albania       0.9957     2.842321e+06
# 2                             Algeria       1.0164     4.490322e+07
# 3                      American Samoa       0.9831     4.427300e+04
# 4                             Andorra       1.0100     7.982400e+04
# 5                              Angola       1.0315     3.558899e+07
# 6                            Anguilla       1.0066     1.585700e+04
# 7                 Antigua and Barbuda       1.0058     9.376300e+04
# 8                           Argentina       1.0052     4.551032e+07
# 9                             Armenia       0.9962     2.780469e+06
# 10                              Aruba       0.9991     1.064450e+05
# 11                          Australia       1.0099     2.617741e+07
# 12                            Austria       1.0020     8.939617e+06
# ...

# %%
#Grouping in order to sort the data in order of growth rate, continent and country while also dispalying the recent population and the corresponding World Population Percentage 
multiple_group = df.groupby(['Growth Rate', 'Continent', 'Country'])[['2022 Population', 'World Population Percentage']].mean()
multiple_group = multiple_group.sort_values(by=['Growth Rate'], ascending=False).reset_index()
multiple_group
# Out:
#      Growth Rate      Continent                           Country  \
# 0         1.0691         Europe                           Moldova
# 1         1.0404         Europe                            Poland
# 2         1.0378         Africa                             Niger
# 3         1.0376           Asia                             Syria
# 4         1.0359         Europe                          Slovakia
# 5         1.0325         Africa                          DR Congo
# 6         1.0319         Africa                           Mayotte
# 7         1.0316         Africa                              Chad
# 8         1.0315         Africa                            Angola
# 9         1.0314         Africa                              Mali
# 10        1.0312         Africa                           Somalia
# 11        1.0304         Africa                            Uganda
# 12        1.0300         Africa                          Tanzania
# ...

# %%
df.loc[(df['Continent'] == 'Asia') & (df['2022 Population'] >= 1.0000e+09)]
# Out:
#          Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# Country
# China       1  CHN    Beijing      Asia     1.425887e+09     1.424930e+09
# India       2  IND  New Delhi      Asia     1.417173e+09     1.396387e+09
#
#          2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# China       1.393715e+09     1.348191e+09     1.264099e+09     1.153704e+09
# India       1.322867e+09     1.240614e+09     1.059634e+09              NaN
#
#          1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# China        982372466.0      822534450.0   9706961.0           146.8933
# India                NaN      557501301.0   3287590.0           431.0675
#
#          Growth Rate  World Population Percentage
# Country
# China         1.0000                        17.88
# India         1.0068                        17.77

# %%
df.sort_values(by=['2022 Population'], ascending=False).head(10)
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# China             1  CHN           Beijing           Asia     1.425887e+09
# India             2  IND         New Delhi           Asia     1.417173e+09
# United States     3  USA  Washington, D.C.  North America     3.382899e+08
# Indonesia         4  IDN           Jakarta           Asia     2.755013e+08
# Pakistan          5  PAK         Islamabad           Asia     2.358249e+08
# Nigeria           6  NGA             Abuja         Africa     2.185412e+08
# Brazil            7  BRA          Brasilia  South America     2.153135e+08
# Bangladesh        8  BGD             Dhaka           Asia     1.711864e+08
# Russia            9  RUS            Moscow         Europe     1.447133e+08
# Mexico           10  MEX       Mexico City  North America     1.275041e+08
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# ...

# %%
df.sort_values(by=['2022 Population'], ascending=False).tail(10)
# Out:
#                            Rank CCA3       Capital      Continent  \
# Country
# Saint Pierre and Miquelon   229  SPM  Saint-Pierre  North America
# Montserrat                  230  MSR        Brades  North America
# Falkland Islands            231  FLK       Stanley  South America
# Niue                        232  NIU         Alofi        Oceania
# Tokelau                     233  TKL      Nukunonu        Oceania
# Vatican City                234  VAT  Vatican City         Europe
# Eswatini                    159  SWZ       Mbabane         Africa
# Norway                      120  NOR          Oslo         Europe
# Palau                       222  PLW     Ngerulmud        Oceania
# Timor-Leste                 155  TLS          Dili           Asia
#
#                            2022 Population  2020 Population  2015 Population  \
# Country
# Saint Pierre and Miquelon           5862.0           5906.0           5978.0
# ...

# %%
df[df['Continent'].str.contains('Europe')]['2022 Population'].nlargest(10)
# Out:
# Country
# Russia            144713314.0
# Germany            83369843.0
# United Kingdom     67508936.0
# France             64626628.0
# Italy              59037474.0
# Spain              47558630.0
# Poland             39857145.0
# Ukraine            39701739.0
# Romania            19659267.0
# Netherlands        17564014.0
# Name: 2022 Population, dtype: float64

# %%
df[df['Continent'].str.contains('Asia')]['2022 Population'].nlargest(10)
# Out:
# Country
# China          1.425887e+09
# India          1.417173e+09
# Indonesia      2.755013e+08
# Pakistan       2.358249e+08
# Bangladesh     1.711864e+08
# Japan          1.239517e+08
# Philippines    1.155590e+08
# Vietnam        9.818686e+07
# Iran           8.855057e+07
# Turkey         8.534124e+07
# Name: 2022 Population, dtype: float64

# %%
df[df['Continent'].str.contains('Africa')]['2022 Population'].nlargest(10)
# Out:
# Country
# Nigeria         218541212.0
# Ethiopia        123379924.0
# Egypt           110990103.0
# DR Congo         99010212.0
# Tanzania         65497748.0
# South Africa     59893885.0
# Kenya            54027487.0
# Uganda           47249585.0
# Sudan            46874204.0
# Algeria          44903225.0
# Name: 2022 Population, dtype: float64

# %%
df['population_change'] = df['2022 Population'] - df['2020 Population'] 
population_change_column = df['population_change']
# Out:
# Country
# Afghanistan                          2156541.0
# Albania                               -24528.0
# Algeria                              1451559.0
# American Samoa                         -1916.0
# Andorra                                 2124.0
# Angola                               2160502.0
# Anguilla                                 272.0
# Antigua and Barbuda                     1099.0
# Argentina                             474286.0
# Armenia                               -25139.0
# Aruba                                   -140.0
# Australia                             507362.0
# Austria                                31840.0
# Azerbaijan                                 NaN
# Bahamas                                 3513.0
# Bahrain                                -5236.0
# Bangladesh                           3765421.0
# Barbados                                 942.0
# Belarus                               -98786.0
# Belgium                                94213.0
# ...

# %%
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...
